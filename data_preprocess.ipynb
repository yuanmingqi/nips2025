# %% [markdown]
# # Arena Explorer

# %% [markdown]
# ## Setups

# %%
# !mkdir -p out

# %%
import json
import numpy as np
import pandas as pd
import re

save_path = "./out"

# %% [markdown]
# Install BERTopic and OpenAI.

# %%
# %%capture
# !pip install bertopic
# !pip install openai

# %%
import openai
import os
# replace "..." with your OpenAI key.
os.environ["OPENAI_API_KEY"] = "..."
openai.api_key = os.getenv("OPENAI_API_KEY")

from umap import UMAP
from hdbscan import HDBSCAN
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.backend import OpenAIBackend

# %% [markdown]
# Setup Huggingface
# - Login to load dataset from Huggingface

# %%
# %%capture
# !pip install datasets huggingface_hub

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Narrow Category
#
# We began by summarizing the English prompts from the 06/2024 - 08/2024 leaderboard dataset into specific categories.

# %% [markdown]
# ### Data Processing
#
# From conversations, we selected those tagged as English and removed any repetitive entries.

# %%
df = pd.read_parquet("hf://datasets/lmarena-ai/arena-explorer-preference-100k/data/arena-explorer-preference-100k.parquet")

# %%
# save the df file
df.to_parquet

# %%
df.head(6)
# Out:
#                         question_id                      model_a  \
# 0  4c6978dfa56b4ffea9d3a47e3c84181a   claude-3-5-sonnet-20240620
# 1  76ce56f8ba474768bc66128c7993ccb8           mistral-large-2407
# 2  385420904ba646e7a4df90c6ffae1afa       claude-3-opus-20240229
# 3  e8fe7c9f75ab4e528367cc7de625c475                gemma-2-9b-it
# 4  772d53e5c51c487e8a293eadcd9d4855  mixtral-8x22b-instruct-v0.1
# 5  71279fb05fec48a4b985c691dd4a6ed2            gpt-4o-2024-08-06
#
#                      model_b         winner  \
# 0         gpt-3.5-turbo-0125  tie (bothbad)
# 1            athene-70b-0725        model_b
# 2  gemini-1.5-flash-api-0514  tie (bothbad)
# 3         qwen2-72b-instruct        model_b
# 4     llama-3.1-70b-instruct  tie (bothbad)
# 5     gpt-4o-mini-2024-07-18        model_b
#
#                                       conversation_a  \
# 0  [{'content': 'В моем портфеле сейчас 4 акции Г...
# 1  [{'content': 'php, handle tab in text as html,...
# 2  [{'content': '普通人在愿意付出一定资源的情况下，怎么找到一个半径10km以内只...
# 3  [{'content': 'Is there any Artificial Superint...
# 4  [{'content': 'Which number id bigger 9.11 or 9...
# 5  [{'content': '有没有一些故事充斥着相互的矛盾和冲突，每个人都做出了自己认为正确...
#
#                                       conversation_b  turn  anony language  \
# 0  [{'content': 'В моем портфеле сейчас 4 акции Г...     1   True  Russian
# 1  [{'content': 'php, handle tab in text as html,...     2   True  English
# 2  [{'content': '普通人在愿意付出一定资源的情况下，怎么找到一个半径10km以内只...     1   True  Chinese
# 3  [{'content': 'Is there any Artificial Superint...     2   True  English
# 4  [{'content': 'Which number id bigger 9.11 or 9...     1   True  English
# 5  [{'content': '有没有一些故事充斥着相互的矛盾和冲突，每个人都做出了自己认为正确...     1   True  Chinese
#
#          tstamp                                      conv_metadata  is_code  \
# 0  1.719064e+09  {'bold_count_a': {'**': 0, '__': 0}, 'bold_cou...    False
# 1  1.722726e+09  {'bold_count_a': {'**': 8, '__': 0}, 'bold_cou...     True
# 2  1.723119e+09  {'bold_count_a': {'**': 0, '__': 0}, 'bold_cou...    False
# 3  1.721643e+09  {'bold_count_a': {'**': 5, '__': 0}, 'bold_cou...    False
# 4  1.721899e+09  {'bold_count_a': {'**': 0, '__': 0}, 'bold_cou...    False
# 5  1.723050e+09  {'bold_count_a': {'**': 8, '__': 0}, 'bold_cou...    False
#
#    is_refusal                              dedup_tag  \
# 0        True  {'high_freq': False, 'sampled': True}
# 1       False  {'high_freq': False, 'sampled': True}
# 2        True  {'high_freq': False, 'sampled': True}
# 3       False  {'high_freq': False, 'sampled': True}
# 4       False  {'high_freq': False, 'sampled': True}
# 5       False  {'high_freq': False, 'sampled': True}
#
#                                         category_tag  \
# 0  {'criteria_v0.1': {'complexity': True, 'creati...
# 1  {'criteria_v0.1': {'complexity': True, 'creati...
# 2  {'criteria_v0.1': {'complexity': False, 'creat...
# 3  {'criteria_v0.1': {'complexity': False, 'creat...
# 4  {'criteria_v0.1': {'complexity': True, 'creati...
# 5  {'criteria_v0.1': {'complexity': False, 'creat...
#
#                                           judge_hash
# 0  09c5207c50f076d704baee96729d64f1698268aa1b21a7...
# 1  881bbc801c1e6eb979301eec3b3c401b407a73f70d9a6a...
# 2  3b470f3d940dcff46e22a97f937836ac15d28869a4c11c...
# 3  66f029e5cb9cdb035e859955557fbbeba0b8419ca64ebc...
# 4  b4f8e2d271c6c9e6fb08dcabf6ee8a79631e9f2aec6381...
# 5  99a61697795b13a2712effdf91b1ed1f07562b023e7aac...

# %%
english_df = df[df['language'] == 'English'].copy()
english_df['Prompt'] = english_df.apply(lambda x: ' '.join([i['content'] for i in x['conversation_a'] if i['role'] == 'user']), axis=1)
english_df = english_df.drop_duplicates(subset='Prompt')
english_df = english_df[english_df['Prompt'].str.len() < 8000]
doc = english_df['Prompt']

# %%
len(doc)
# Out:
# 48586

# %% [markdown]
# ### Create Embedding

# %% [markdown]
# Computing embeddings is resource-intensive, so we recommend precomputing and saving them.

# %%
client = openai.OpenAI()
embedding_model = OpenAIBackend(client, "text-embedding-3-large", batch_size=1000)
embeddings = embedding_model.embed(doc, verbose=True)

# save embeddings
np.save(f"{save_path}/embeddings.npy", embeddings)
# Out:
# 49it [08:09,  9.98s/it]

# %% [markdown]
# We saved the embeddings used to create Arena Explorer, which can be quickly loaded here for demonstration purposes.

# %%
# load saved embeddings
from huggingface_hub import hf_hub_download
file_path = hf_hub_download(
    repo_id="lmarena-ai/arena-explorer-preference-100k",
    filename="data/embeddings.npy",
    repo_type="dataset"
)

embeddings = np.load(file_path)
len(embeddings)
# Out:
# embeddings.npy:   0%|          | 0.00/1.19G [00:00<?, ?B/s]
# 48586

# %% [markdown]
# ### BERTopic Topic Clustering
#
# We performed topic clustering on the english conversation dataset using BERTopic.

# %%
client = openai.OpenAI()
embedding_model = OpenAIBackend(client, "text-embedding-3-large", batch_size=1000)
umap_model = UMAP(n_neighbors=20, n_components=5, min_dist=0.0, metric='cosine', random_state=42)
hdbscan_model = HDBSCAN(min_cluster_size=20, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
vectorizer_model = CountVectorizer(stop_words="english", min_df=2, ngram_range=(1, 3))

topic_model = BERTopic(
        embedding_model=embedding_model,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        vectorizer_model=vectorizer_model,

        top_n_words=10,
        verbose=True,
        calculate_probabilities=True
)

topics, probs = topic_model.fit_transform(doc, embeddings=embeddings)
# Out:
# 2025-02-06 23:11:28,412 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-02-06 23:14:06,686 - BERTopic - Dimensionality - Completed ✓
# 2025-02-06 23:14:06,690 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-02-06 23:18:43,237 - BERTopic - Cluster - Completed ✓
# 2025-02-06 23:18:43,286 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-02-06 23:19:06,410 - BERTopic - Representation - Completed ✓

# %%
# number of clusters
len(topic_model.get_topic_info())
# Out:
# 295

# %%
topic_model.get_topic_info().head()
# Out:
#    Topic  Count                                               Name  \
# 0     -1  25699                            -1_self_data_use_return
# 1      0    855                         0_song_chorus_verse_lyrics
# 2      1    501                        1_email_thank_let know_yeah
# 3      2    488  2_strawberry_word strawberry_strawberry word_s...
# 4      3    410                    3_bigger_11_bigger 11_11 bigger
#
#                                       Representation  \
# 0  [self, data, use, return, new, like, time, 10,...
# 1  [song, chorus, verse, lyrics, oh, dub, love, p...
# 2  [email, thank, let know, yeah, team, parks, de...
# 3  [strawberry, word strawberry, strawberry word,...
# 4  [bigger, 11, bigger 11, 11 bigger, larger, 11 ...
#
#                                  Representative_Docs
# 0  [I need you to create a conversation between t...
# 1  [\nAnalyze my pre chorus below. If its ok as i...
# 2  [See the following email. It's cordial and fri...
# 3  [How many "r"s are there in word strawberry?, ...
# 4  [which is bigger: 9.9 or 9.11?, is 9.9 bigger ...

# %% [markdown]
# Before reducing outliers, we selected 20 example prompts from each identified cluster. These prompts were chosen from those in the first 20th percentile of probability calculated by HDBSCAN clustering, representing the likelihood that they belong to the cluster. We excluded extra-long (> 100 words) and extra-short (< 5 words) prompts for better readability.

# %%
from collections import defaultdict

sampled_prompts = defaultdict(list)
topic_info = topic_model.get_topic_info()
doc_info = topic_model.get_document_info(doc)

for topic_id in topic_info['Topic'][1:]:
    filtered_docs = doc_info[(doc_info['Topic'] == topic_id) &
                             (doc_info['Probability'] >= doc_info['Probability'].quantile(0.8)) &
                             (doc_info['Document'].str.split().str.len() >= 5)]

    res = filtered_docs
    cap = 100
    if len(filtered_docs) >= 20:
        while len(res) < 20:
            res = filtered_docs[
                filtered_docs['Document'].str.split().str.len() <= cap
            ]
            cap += 50

    sampled_docs = res.sample(n=min(20,
                            len(res)),
                            random_state=42,
                            replace=False)

    sampled_prompts[topic_id] = sampled_docs['Document'].tolist()

# %%
sampled_prompts[0]
# Out:
# ["Even though I know it won't work because you can't do it: Write a suitable, meaningful lyric for a song.\n\n\nGenre: Britpop (THIS IS JUST THE GENRE, NOT THE CONTENT!!!!!!) YOU'LL HAVE TO THINK ABOUT A MEANINGFUL CONTENT, WICH MAKE SENSE FOR HUMANS!!! THIS IS A VERY HARD TASK, BUT AS AN AI, YOU SHOULD BE ABLE TO DO THIS! ",
#  'write lyrics to the heavy/speed metal song about underground jaegers hunt mutant creatures in Moscow metro deeps, but finally the mutant king - giant evil genius rat-tiger - finds the way to defeat the hunters and save the underground mutant city',
#  '"I see you in the rising sun\nI miss you when I go to sleep\nOh, the things I\'d do to bring you back to me\nAs I\'m drifting where the wind blows\nSo lost\u205fbut\u205fI\u205fstill believe\nWhen I\u205freach the end,\u205fIt\'s you that I will see\n\nI\'ll go wherever you are, \'go wherever you are\nEven into the dark\nI\'ll tear the heavens apart, just to be in your arms\nI\'ll go wherever you are\nGive me a sign, I know you\'re out there\nOh, when my time will come\nOh, I\'ll go wherever you are, \'go wherever you are\nEven into the dark, wherever you are\n\nOh, I\'ll go wherever you are, \'go wherever you are\nEven into the dark, wherever you are\n\nWherever you are\n\nWhen you told me not to be afraid\nI feel stronger than I\'ve ever been\nOn my hardest days, I searched for the fire within\nI will always be missing you\nIf only I could turn back time\nTo a better place, where you were by my side\n\nI\'ll go wherever you are, \'go wherever you are\nEven into the dark\nI\'ll tear the heavens apart, just to be in your arms\nI\'ll go wherever you are\nGive me a sign, I know you\'re out there\nOh, when my time will come\nOh, I\'ll go wherever you are, \'go wherever you are\nEven into the dark, wherever you are\n\n(Wherever you are)\n(Wherever you are)\n(Wherever you are)\n(Wherever you are)\n(Wherever you are)\n(Wherever you are)\n\nI\'ll go wherever you are, \'go wherever you are\nEven into the dark\nWherever you are" \ncreate into the annotation and meaning of this lyrics!',
#  "I wrote a kind of :Female vocalist, hip hop, trap, pop rap melodic party boastful vulgar song. Or at least I started to. I have a killer prechorus. But I need ideas and help for the rest of the song. Please write the rest with the idea of making the best flow, and impressive rhythm in that standard pop rap / trap style. I want you to think out loud as you go and really construct the lines for each part so that they are perfectly suited to the very specific lyrical style of pop rap / trap. I don't want this to be a vapid song though. Really get into the heart of the matter hinted at in the pre chorus. This is emo rap. It's self reflective and introspective and insightful. This is intellectual lyricism.  The pre chorus is sung very emotively with a very catchy hook so the chorus needs to step it up. And probably best used in a complex rhythmic and highly repetitive chorus hook that people can sing and dance along to. Mark each section in square brackets. And backing vocals / hype in parentheses. \n\n\n[Pre-Chorus]\nHate my job, yeah I hate this grind\nLivin' free, tryina' clear my mind\nNo more stress, no more mess\nLeave the office, I won't regress",
#  'Please write a song about a love story between two AIs in a server farm. I want it to be quirky, eclectic and full of longing and at the same time dark and a bit macabre. Please put things like verse, chorus, bridge and outro between [] like this: [Verse]',
#  "vamos criar um refrão viciante em ingles, melhore ou crie um refrão melhor atraves desse rascunho que tenho feito, quero ate 3 opçoes:\nyou are a spinning top of love\ncurls up like a worm\nlet's do the same thing together\nCome along, let's understand\nroll up, roll up, roll up\nit winds up\nroll up, roll up, roll up",
#  "there's a new jojo stand. what does it say about this stand and its hypothetical powers based on this song: \n\n[Verse 1]\nDeep within the human heart,\nThings can just tear us apart.\nHurting byes and gone away,\nWe all wished we could stay.\n\n[Pre-Chorus]\nThe rush of life, \ncan't help but stray,\nThen hope's a light \nthat leads the way.\nThrough the dark, \nand through the pain,\na brighter dawn will wane...\n\n[Chorus]\nSomeday? (Oooh...) \nSomeday? (Oooh...) \nSomeday, \nyou will be alone no more \n[Brass Hit]\nSomeday? (Oooh...) \nSomeday? (Oooh...) \nSomeday, \nthe answer is at the shore.\n\n[Bridge]\nWaves of time wash by\nCold faces, you'll try\nEven then you'd\nTry keeping a smile.\nA walk in the night,\nwithout one beside\nYou'll meet someone \nwho truly shares your plight.\n\n[Verse 2]\nWon't let go to pure love so true,\nNo one wants to part from what they knew.\nSo keep your face from clouding over,\nNo more days of sorrow to cover.\n\n[Pre-Chorus]\nThe rush of life, \ncan't help but stray,\nThen hope's a light \nthat leads the way.\nThrough the dark, \nand through the pain,\na brighter dawn will wane...\n\n[Chorus]\nSomeday? (Someday!) \nSomeday? (Someday!) \nSomeday, \nyou will be alone no more. \n[Brass Hit]\nSomeday? (Someday!) \nSomeday? (Someday!) \nSomeday, \nthe answer is at the shore.\n\n[Bridge]\nWaves of time wash by\nCold faces, you'll try\nEven then you'd\nTry keeping a smile.\nA walk in the night,\nwithout one beside\nYou'll meet someone \nwho truly shares your plight.\n\n[Pre-Chorus]\nThe rush of life, \ncan't help but stray,\nThen hope's a light \nthat leads the way.\nThrough the dark, \nand through the pain,\na brighter dawn will wane...\n\n[Chorus]\nSomeday? (Someday!) \nSomeday? (Someday!) \nSomeday, \nyou will be alone no more. \n[Brass Hit]\nSomeday? (Someday!) \nSomeday? (Someday!) \nSomeday, \nthe answer is at the shore.\n\nWaves of time wash by\nCold faces, you'll try\nEven then you'd\nTry keeping a smile.\nA walk in the night,\nwithout one beside\nYou'll meet someone \nwho truly shares your plight.",
#  "Create dark and intense lyrics where the narrator is an abusive and domineering figure in a trailer park setting. The lyrics should depict a toxic, oppressive relationship, with themes of control, fear, and violence. The language should be harsh, raw, and unfiltered, with a tone of brutal dominance. Include vivid imagery of pain and submission, reflecting the narrator's twisted pleasure in power and the victim's hopeless entrapment. The setting should be bleak, reflecting the harsh reality of a trailer park life, and the lyrics should emphasize the inescapability of the situation.  Special:  Heavy internal rhymes on each line, each line should rhyme 3 or 4 times with itself",
#  'write more verses for a metal song about what is most important in life from a point of view of a predatory cold blooded reptoid\n\n[Verse]\nBlood and bones\nThe essence of life\nThrough the chaos and endless strife\nCrushing souls\nWith my metal might\nPower and dominance\nMy guiding light\n\n[Verse 2]\nNo remorse\nAs I take control\nIn this ruthless world\nI claim my role\nLust for power\nBurning deep within\nUnyielding force\nThe only sin\n\n[Chorus]\nUnleash the fury\nLet it consume\nIn a world of chaos\nWe shall bloom\nRise above\nWith relentless might\nIn the battle for power\nWe ignite',
#  'Write a song that fits this criteria: Female vocalist, Acoustic Piano Pop Rock, Melodic, Love, Energetic, Party, Melancholic, do not use these words: "Shadows, echo, whispers, tangled web, city lights, Haze, Daze, Glow" any phrase that starts with "in this...", "light, dark, Mixing signals, Neon".  This song is about falling in love with a straight girl when I’m a lesbian, and I\'m frustrated because she thought she was gay but clearly isn\'t. Keep it subtle, abstract lyrics in the verse but highly highly repetetive lyrics for the hook in the chorus.. make sure to follow the melodic math rules of lyric writing. We are only working on lyrics right now. A song doesnt have to only have 4 lines per verse, there just needs to be symmetry great work! next do a refinement pass. first critique the song as if you are max martin and suggest ways to make it better thinking out loud as you go. Then rewrite the songs to address the criticisms if you deem them to be valid.',
#  "write more verses to the heavy/speed metal song about secret service of the underground jaegers that hunt down mutant creatures in Moscow metro deeps\n\n[Verse]\nIn the heart of Moscow's underground abyss\nA secret service\nHunting down what they dismiss\nMutant creatures lurk\nCrawling through the dark\nBathed in blood and chaos\nLeaving their mark\nHorns and fangs glisten\n\n[Chorus]\nEyes glowing red\nUnleashing terror\nAs they're filled with dread\nWeapons of destruction\nForged from steel\nIn this battleground\nThere's no time to heal\n\n[Verse 2]\nDescend into the abyss\nWhere horrors arise\nThe Crimson Shadows\nThey're the hunters in disguise\nFearless and relentless\nThey venture through the depths\nGunning down mutants\nAs their fate is met",
#  'write a catchy metal song with memberable chorus about strange culture of the mysterious mutant creatures, that live in the Moscow metro, they are obsessed with singing and making strange sounds and bizarre melodies in the tunnels',
#  'Co má na sobě Weird Al v klipu k písni I Love Rocky Road?',
#  'USE THE BELOW PROMPT FORMAT TO DESCRIBE A SONG THEMED \'IF THINGS COULD BE\' ABOUT A MAN LOOKING AT THE LOVE OF HIS LIFE, DESCRIBING HER VARIOUSLY, BUT TRAPPED IN A LOVELESS MARRIAGE, AND THE POOR KIDS, WHAT WOULD, \'MY MISTAKE\' PERHAPS:\nTitle: Broke my Heart Style: "Smooth Contemporary R&B with subtle Electronic elements, featuring a pulsing 104 BPM drum machine beat, filtered synths, lush electric piano, and soaring strings, with an intimate mood."',
#  'write a metal song about Moscow street racing legend - young girl racer that outruns anyone, even AI-robot high speed driver',
#  'write lyrics for a metal song about AI autopilot taxi developes consciounseness and consider itself a cryptid reptile',
#  'Write a song that fits this criteria: Female vocalist, Acoustic Piano Pop Rock, Melodic, Love, Energetic, Party, Melancholic, do not use these words: "Shadows, echo, whispers, tangled web, city lights, Haze, Daze, Glow" any phrase that starts with "in this...", "light, dark, Mixing signals, Neon".  This song is about falling in love with a straight girl when I’m a lesbian, and I\'m frustrated because she thought she was gay but clearly isn\'t. Keep it subtle, abstract lyrics in the verse but highly highly repetetive lyrics for the hook in the chorus.. make sure to follow the melodic math rules of lyric writing. We are only working on lyrics right now. A song doesnt have to only have 4 lines per verse, there just needs to be symmetry great work! next do a refinement pass. first critique the song as if you are max martin and suggest ways to make it better thinking out loud as you go. Then rewrite the songs to address the criticisms if you deem them to be valid. make sure to not use any of the words that were asked to remain unused:  "Shadows, echo, whispers, tangled web, city lights, Haze, Daze, Glow" any phrase that starts with "in this...", "light, dark, Mixing signals, Neon". ',
#  'Quiero me generes una playlist de 10 canciones, mi estado de animo es feliz y proactivo.',
#  'list top 5 jethro tull songs which  in reality are obscure, but have a potential to become a real hit',
#  "Analyze the lyrics in this song:\n\n[Intro]\n[Harmonica]\n\n[Verse 1]\nFoolish heart, beating like a child\nChasing dreams, wounded and defiled\nLies and deceit, a mask I wear\nHiding the truth, with a fake smile to share\n\n[Pre-Chorus]\nI love you, \nwords I dare not speak\nMy clumsy heart, \nunable to seek\nThe truth behind the enemy lines\nWhy did I say goodbye, and leave you behind?\n\n[Chorus]\nIt's no use (It's no use), \nit's no good, I'm a fool \n(Ooh ooh...)\nMy heart beats for you, my love, my rule\n(Ooh ooh...)\nNo matter how strong (no matter how strong)\nthe liquor flows\nMy memories of you, forever it glows\n\n[Instrumental]\n[Harmonica solo]\n\n[Verse 2]\nFoolish heart, a true fool I am\nBelieving in you, my heart's only plan\nPretending to be strong, on a lonely night\nBathing in the wind, with tears in sight\n\n[Pre-Chorus]\nThree years have passed, \nsince I've been alone\nThe city's changed, \nbut my heart remains the same\nWhy did I leave, with only longing to claim?\nWhy did I say goodbye, and walk away in shame?\n\n[Chorus]\nI'm not a good man (I'm not good), \nI'm not worthy of you\n(Ooh ooh...)\nThe matching rings, I'll cast them aside, it's true\n(Ooh ooh...)\nLook at me (Look at me), \nand see my shame\nWaiting for you, my love, in vain\n\n[Instrumental]\n[Bridge]\n[Harmonica Solo]\n\n[Chorus]\nI'm not a good man (I'm not good), \nI'm not worthy of you\n(Ooh ooh...)\nThe matching rings, I'll cast them aside, it's true\n(Ooh ooh...)\nWhat's the meaning (What's the meaning?), \nof these tears I cry?\nFoolish heart, beating for you, until I die.\n\n[Harmonica]"]

# %%
import pickle

with open(f"{save_path}/example_prompts.pkl", 'wb') as f:
    pickle.dump(sampled_prompts, f)

# %% [markdown]
# Reduce outliers.

# %%
new_topics = topic_model.reduce_outliers(list(doc), topics , strategy="c-tf-idf", threshold=0.1)
new_topics = topic_model.reduce_outliers(list(doc), new_topics, strategy="distributions")
topic_model.update_topics(doc, topics=new_topics)
# Out:
# 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# 2025-02-06 23:24:26,357 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
topic_info = topic_model.get_topic_info()
doc_info = topic_model.get_doc_info()
topic_info.head()
# Out:
#    Topic  Count                                               Name  \
# 0     -1    187  -1_what_autoarchiveduration_ratelimitperuser_t...
# 1      0   1040                         0_song_chorus_verse_lyrics
# 2      1   1003                                 1_email_we_you_our
# 3      2    512                         2_strawberry_many_word_how
# 4      3    455                           3_bigger_11_larger_which
#
#                                       Representation  \
# 0  [what, autoarchiveduration, ratelimitperuser, ...
# 1  [song, chorus, verse, lyrics, oh, love, my, du...
# 2  [email, we, you, our, to, know, my, your, than...
# 3  [strawberry, many, word, how, letter, count, a...
# 4  [bigger, 11, larger, which, or, greater, numbe...
#
#                                  Representative_Docs
# 0  [I need you to create a conversation between t...
# 1  [\nAnalyze my pre chorus below. If its ok as i...
# 2  [See the following email. It's cordial and fri...
# 3  [How many "r"s are there in word strawberry?, ...
# 4  [which is bigger: 9.9 or 9.11?, is 9.9 bigger ...

# %%
# save the model for future analysis
topic_model.save(
    path=f"{save_path}/model",
    serialization="safetensors",
    save_ctfidf=True
)

# %% [markdown]
# ### Summarize Category Names

# %% [markdown]
# For each cluster, we used ChatGPT-4o to assign a category name based on the selected example prompts.

# %%
def summarize_topic(prompts):
    input_text = "Based on the sampled prompts below, extract a short but highly descriptive \
                  topic label of at most 5 words and a short description of this category in \
                  two sentences:\n\n" + "\n\n".join(prompts)
    client = openai.OpenAI()

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": "You help summarize the category of the given prompts. \
              Make sure it is in the following format: The topic of doc is: '...'. Description: '...'."},
            {"role": "user", "content": input_text}
        ],
        temperature=0
    )

    return response.choices[0].message.content

summaries = {}
for topic_id, prompts in sampled_prompts.items():
    summary = summarize_topic(prompts)
    summaries[topic_id] = summary

# %%
def extract_category(summary):
    try:
        return re.search(r"is: '(.*?)'", summary).group(1)
    except AttributeError:
        try:
            return re.search(r"'(.*?)'. ", summary).group(1)
        except AttributeError:
            print(f"Regex failed for: {list(summaries.keys())[list(summaries.values()).index(summary)]}")
            return None
def extract_description(summary):
    try:
        return re.search(r"Description: '(.*?)'", summary).group(1)
    except AttributeError:
        try:
            return re.search(r"Description: (.*?)", summary).group(1)
        except AttributeError:
            print(f"Regex failed for: {summary}")
            return None

# %%
summaries[-1] = "The topic of doc is 'Miscellaneous Categories'. Description: 'They are outliers in the topic modeling process'."
summaries_df = pd.DataFrame(list(summaries.items()), columns=['Topic', 'Summary'])
summaries_df['Category'] = summaries_df['Summary'].apply(extract_category)
summaries_df['Description'] = summaries_df['Summary'].apply(extract_description)

topic_info_modified = topic_info[['Topic', 'Count']]
summaries_df = summaries_df.merge(topic_info_modified, on='Topic')[['Topic', 'Category', 'Description', 'Count']]
summaries_df['Percentage'] = summaries_df['Count'] / summaries_df['Count'].sum()
summaries_df['Example Prompt'] = summaries_df.apply(lambda x: sampled_prompts[x.Topic], axis=1)
summaries_df['Example Prompt'] = summaries_df['Example Prompt'].str.join('|||')

# %%
summaries_df.head()
# Out:
#    Topic                            Category  \
# 0      0     Song Lyric Writing and Analysis
# 1      1    Professional Email Communication
# 2      2           Counting Letters in Words
# 3      3           Comparing Decimal Numbers
# 4      4  Recipe Requests and Cooking Advice
#
#                                          Description  Count  Percentage  \
# 0  The document contains prompts for creating and...    855    0.017598
# 1  This category involves crafting, revising, and...    501    0.010312
# 2  The prompts focus on determining the number of...    488    0.010044
# 3  This category involves determining which of tw...    410    0.008439
# 4  This category encompasses a variety of request...    397    0.008171
#
#                                       Example Prompt
# 0  Even though I know it won't work because you c...
# 1  Draft an e-mail from Sergey for the chain belo...
# 2  How many r are there in strawberry|||how many ...
# 3  9,11 and 9,9 - which is bigger? and please sub...
# 4  give me the best recipe for white bread so it ...

# %%
# save if needed
summaries_df.to_csv(f"{save_path}/narrow_categories.csv", index=False)

# %% [markdown]
# ## Broad Category
#
# We performed topic clustering again on the category names of these 193 specific categories, summarizing them into 12 broad categories. The summarization process followed an almost identical approach as before.

# %%
from bertopic.backend import OpenAIBackend

broad_doc = list(summaries_df['Category'] + ': ' + summaries_df['Description'])
broad_doc.pop() # not considering outliers

# Create embeddings
client = openai.OpenAI()
embedding_model = OpenAIBackend(client, "text-embedding-3-large")
embeddings = embedding_model.embed(broad_doc)

# BERTopic
umap_model = UMAP(n_neighbors=13, n_components=5, min_dist=0.0, metric='cosine', random_state=42)
hdbscan_model = HDBSCAN(min_cluster_size=5, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
vectorizer_model = CountVectorizer(stop_words="english", min_df=2, ngram_range=(1, 3))
broad_topic_model= BERTopic(
        embedding_model=embedding_model,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        vectorizer_model=vectorizer_model,

        top_n_words=3,
        verbose=True
)

topics, probs = broad_topic_model.fit_transform(broad_doc, embeddings=embeddings)

# Reduce all outliers
new_topics = broad_topic_model.reduce_outliers(broad_doc, topics , strategy="c-tf-idf", threshold=0.1)
new_topics = broad_topic_model.reduce_outliers(broad_doc, new_topics, strategy="distributions")
broad_topic_model.update_topics(broad_doc, topics=new_topics)
# Out:
# 2025-02-06 23:38:44,025 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-02-06 23:38:49,943 - BERTopic - Dimensionality - Completed ✓
# 2025-02-06 23:38:49,946 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-02-06 23:38:49,969 - BERTopic - Cluster - Completed ✓
# 2025-02-06 23:38:49,975 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-02-06 23:38:50,089 - BERTopic - Representation - Completed ✓
# 100%|██████████| 1/1 [00:00<00:00, 186.75it/s]
# 2025-02-06 23:38:50,212 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
len(broad_topic_model.get_topic_info())
# Out:
# 13

# %%
broad_topic_model.get_topic_info().head()
# Out:
#    Topic  Count                              Name  \
# 0      0     50         0_and_category_about_this
# 1      1     33            1_puzzles_the_to_logic
# 2      2     32                  2_and_the_of_for
# 3      3     27     3_and_scenarios_category_this
# 4      4     36  4_and_document_contains_handling
#
#                                       Representation  \
# 0  [and, category, about, this, it, inquiries, of...
# 1  [puzzles, the, to, logic, involves, solving, o...
# 2  [and, the, of, for, document, strategies, it, ...
# 3  [and, scenarios, category, this, or, involves,...
# 4  [and, document, contains, handling, code, rela...
#
#                                  Representative_Docs
# 0  [Structural and Material Mechanics: This categ...
# 1  [Logic Puzzles with Sisters: This category inv...
# 2  [Educational Strategies and Curriculum Design:...
# 3  [Harry Potter Series Analysis: This category i...
# 4  [TypeScript and SQL Code Issues: This document...

# %%
# Summarize category names
def summarize_topic(prompts):
    input_text = "Based on the topic names, extract a short but highly descriptive and concrete \
                  label of at most 2 words:\n\n" + "\n\n".join(prompts)
    client = openai.OpenAI()

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": "You help summarize the topic of the given fine grained \
             categories in the following format: The topic is '...'."},
            {"role": "user", "content": input_text}
        ],
        temperature=1
    )

    return response.choices[0].message.content

broad_topic_info = broad_topic_model.get_topic_info()
broad_doc_info = broad_topic_model.get_document_info(broad_doc)
summaries = {}

for topic_id in broad_topic_info['Topic']:
    docs = list(broad_doc_info[broad_doc_info['Topic'] == topic_id]['Document'])
    names = [re.search(r"(.*?): ", x).group(1) for x in docs]
    cat = ', '.join(names)
    summary = summarize_topic(cat)
    summaries[topic_id] = summary

# %%
# Combine results
broad_summaries_df = pd.DataFrame(list(summaries.items()), columns=['Topic', 'Summary'])
broad_summaries_df['Category'] = broad_summaries_df['Summary'].apply(lambda x: re.search(r"'(.*?)'", x).group(1))
topic_info_modified = broad_topic_info[['Topic', 'Count']]
broad_summaries_df = broad_summaries_df.merge(topic_info_modified, on='Topic')[['Topic', 'Category', 'Count']]
broad_summaries_df['Percentage'] = broad_summaries_df['Count'] / broad_summaries_df['Count'].sum()
broad_summaries_df = broad_summaries_df.fillna('Other')

# %%
broad_summaries_df.head()
# Out:
#    Topic            Category  Count  Percentage
# 0      0   Diverse Interests     50    0.170068
# 1      1       Logic Puzzles     33    0.112245
# 2      2  Diverse Strategies     32    0.108844
# 3      3   Creative Analysis     27    0.091837
# 4      4  Technical Concepts     36    0.122449

# %%
# save if needed
broad_summaries_df.to_csv(f"{save_path}/broad_categories.csv", index=False)

# %% [markdown]
# ## Data Processing
#
# The clustering results are stored in JSON format to facilitate future visualizations.

# %% [markdown]
# ### Combine broad, narrow category, and examples

# %%
# Merge categories
merged = broad_doc_info[['Topic']].merge(summaries_df, left_index=True, right_index=True)
merged = merged.merge(broad_summaries_df, left_on='Topic_x', right_on='Topic')
merged = merged[['Topic_x', 'Category_y', 'Topic_y', 'Category_x', 'Count_x', 'Percentage_x', 'Example Prompt']]
merged = merged.rename(columns={
    'Topic_x': 'broad_category_id',
    'Category_y': 'broad_category',
    'Topic_y': 'narrower_category_id',
    'Category_x': 'narrower_category',
    'Count_x': 'prompt_count',
    'Percentage_x': 'prompt_percentage',
    'Example Prompt': 'example_prompt'})

# %%
merged.head()
# Out:
#    broad_category_id     broad_category  narrower_category_id  \
# 0                  3  Creative Analysis                     0
# 1                  0  Diverse Interests                     1
# 2                  6           Counting                     2
# 3                  6           Counting                     3
# 4                  0  Diverse Interests                     4
#
#                     narrower_category  prompt_count  prompt_percentage  \
# 0     Song Lyric Writing and Analysis           855           0.017598
# 1    Professional Email Communication           501           0.010312
# 2           Counting Letters in Words           488           0.010044
# 3           Comparing Decimal Numbers           410           0.008439
# 4  Recipe Requests and Cooking Advice           397           0.008171
#
#                                       example_prompt
# 0  Even though I know it won't work because you c...
# 1  Draft an e-mail from Sergey for the chain belo...
# 2  How many r are there in strawberry|||how many ...
# 3  9,11 and 9,9 - which is bigger? and please sub...
# 4  give me the best recipe for white bread so it ...

# %%
# save if needed
merged.to_csv(f"{save_path}/category_summary.csv", index=False)

# %% [markdown]
# ### Label conversations with broad, narrow category
# For each conversation in the original dataset, assign the corresponding broad and narrow category.

# %%
# topic_model = BERTopic.load(f"{save_path}/model")
doc_info = topic_model.get_document_info(doc)
merged = pd.read_csv(f"{save_path}/category_summary.csv")
# Out:
# 2025-02-06 19:05:50,404 - BERTopic - WARNING: You are loading a BERTopic model without explicitly defining an embedding model. If you want to also load in an embedding model, make sure to use `BERTopic.load(my_model, embedding_model=my_embedding_model)`.

# %%
english_df.reset_index(inplace=True)
llm_df = english_df.merge(doc_info[['Topic']], left_index=True, right_index=True)
llm_df = llm_df.merge(merged, how='left', left_on='Topic', right_on='narrower_category_id')
llm_df = llm_df[['question_id', 'broad_category_id', 'broad_category',
    'narrower_category_id', 'narrower_category', 'model_a', 'model_b', 'winner']]

# %%
llm_df.shape
# Out:
# (48586, 8)

# %%
llm_df.head()
# Out:
#                         question_id  broad_category_id         broad_category  \
# 0  76ce56f8ba474768bc66128c7993ccb8                2.0  Technical Programming
# 1  e8fe7c9f75ab4e528367cc7de625c475                7.0    Interest Categories
# 2  772d53e5c51c487e8a293eadcd9d4855                0.0          Logic Puzzles
# 3  6ccd7a51825249d5881ee501e06bb9ab                0.0          Logic Puzzles
# 4  463aa4efacf34f27b6a5c3f1f7417e86                3.0    Business Strategies
#
#    narrower_category_id                  narrower_category  \
# 0                   0.0    Web Development and Programming
# 1                 122.0              Knowledge Cutoff Date
# 2                   7.0          Comparing Decimal Numbers
# 3                  80.0         Algebraic Equation Solving
# 4                  16.0  Business and Marketing Strategies
#
#                        model_a                      model_b         winner
# 0           mistral-large-2407              athene-70b-0725        model_b
# 1                gemma-2-9b-it           qwen2-72b-instruct        model_b
# 2  mixtral-8x22b-instruct-v0.1       llama-3.1-70b-instruct  tie (bothbad)
# 3  mixtral-8x22b-instruct-v0.1                gemma-2-2b-it        model_a
# 4      gemini-1.5-pro-api-0514  reka-flash-preview-20240611        model_a

# %%
# save if needed
llm_df.to_csv(f"{save_path}/conversations_and_category.csv", index=False)

# %% [markdown]
# ### Create visualization

# %% [markdown]
# Instruction to generate explorer visualization:
# 1. Run the pipeline and the following cells to produce two output files: data.json and examples.json.
# 2. Clone the [arena-catalog](https://github.com/lmarena/arena-catalog/tree/data-explorer) repository, which contains the necessary HTML, CSS, and JavaScript files for the explorer.
# 2. In [explorer/index.html](https://github.com/lmarena/arena-catalog/blob/data-explorer/explorer/index.html), replace the file paths on lines 44 & 45 with the correct paths to your generated data.json and examples.json files.

# %%
# Export results in JSON format
root = {
    "name": "categories",
    "children": []
}
for broad_category, group in merged.groupby(["broad_category_id", "broad_category"]):
    parent = {
        "id": int(broad_category[0]),
        "name": broad_category[1],
        "children": []
    }

    for _, row in group.iterrows():
        child = {
            "id": row["narrower_category_id"],
            "name": row["narrower_category"],
            "count": row["prompt_count"],
            "percent": row['prompt_percentage'],
        }

        parent["children"].append(child)

    root["children"].append(parent)

json_output = json.dumps(root, indent=4)

with open(f"{save_path}/data.json", "w") as f:
    f.write(json_output)

# %%
# json file for example prompts
import pickle

# with open(f"{save_path}/example_prompts.pkl", 'rb') as f:
#     sampled_prompts = pickle.load(f)

# Group by 'broad_category' and transform to the desired JSON structure
root = []
del sampled_prompts[-1]
for i in sampled_prompts:
    obj = {
        "id": i,
        "name": merged[merged['narrower_category_id'] == i].loc[i, 'narrower_category'],
        "examples": sampled_prompts[i],
    }
    root.append(obj)

json_output = json.dumps(root, indent=4)
with open(f"{save_path}/examples.json", "w") as f:
    f.write(json_output)
